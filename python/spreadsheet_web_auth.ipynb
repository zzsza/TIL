# %%
import pydata_google_auth
import gspread

# %%
SCOPES = [
  'https://www.googleapis.com/auth/drive',
  'https://www.googleapis.com/auth/spreadsheets'
]

credentials = pydata_google_auth.get_user_credentials(SCOPES, auth_local_webserver=True)
credentials.access_token = credentials.token

# %%
gc = gspread.authorize(credentials)

# %%
gc.list_spreadsheet_files()
# Out:
# [{'kind': 'drive#file',
#   'id': '1fYaEI8vz26N3R2VaxrlNnk9fMQ8zIy4RpvjRp4jZd0Q',
#   'name': 'Javascript Tutorial - Task Manager',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1XPNYlvKmCtGOGdtXciauxxtgvCSdY0_cpVqdAcrNUWs',
#   'name': '모두의 연봉',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1sOtCHJy9qmM2UZXvjwi0MJfm8T4wQDDMJkD-SJPCcbk',
#   'name': 'CS용어_20171124.xlsx',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1_lGZQpz9YDwLB6m37CJEkyMIHy2juESLaTY7hRb9jyc',
#   'name': 'BOAZ 주소록',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1xrhQ-v9g5cQrX96xy4s_1ppjC5lFJGxGrwUhekRYzMs',
#   'name': '딥놀_스케줄표_2019_하반기',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1cKlSBVa96IewNKIYWWJWl_n4yOemjfC_MnYa2AiXmFg',
#   'name': '4. 올인원 패키지 : 머신러닝과 데이터분석 A-Z_커리큘럼_변성윤님',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1g1_KO52dqZ0g-mYyhQGOgQIGF_7gl70V98-dbMu9rVM',
#   'name': 'geultto-genie-0722',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1w_EuL5Tj7o8M4jNLVHkfOUJPJErsvNwSzScdaZ6YOi8',
#   'name': '글또 3기 현황판',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1k-ze3VJUPg-91K0tayTjixEum0W3Bexo6SZxpkz8YiI',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '101AV8wu7cqMMQZ2wS67wsbMCr32HfbIt48M0HJ4dfiE',
#   'name': '글또 3기 참가 신청서(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1u9UwDsdS_SZsnb5EmzAoN-OhhEa2ZZcOB5kOgbbCt_Y',
#   'name': '글또 글 체크',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1-YU5pF4H4yCym1hl6a9c38YTtptJOWinKesI-1doVUQ',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1qdDVAJ027Hdp3zUbBSEev_uZMNiz7ggxq8pijG9F5tA',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1CCGO6FjA9Vc-kdgYWo2-lXdWxoU_NlTtJzecBAcad5I',
#   'name': '2014년 정부지원사업 중 스타트업이 신청할만한 것들의 진행과정 정리',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1VB9c4yXu72rjHq3AKVR0GPc852GmsPCPmLSISIUTwcE',
#   'name': '스밥 호스트 모집 (Responses)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1-MfqiOUCQPz7XyxBmXWnC9UQszX1BbvHn62ZloP75Q8',
#   'name': '책을 팝니다',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1zIDm-cykASbShXU558SFjCASdNh5rIF4LUKzoyEram8',
#   'name': 'Spark Official Tutorial',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1t3l8xm4X2ENON7bw8eoMs9VyTcrcNSVIZ18fvQiN_SM',
#   'name': '2019 Intermediate python 커리큘럼',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1L0jikAvte2eARFLbLOQIwLEqehjbZRqGxmejtq7beaQ',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1mjAveni_giwwOcDzVCqoEP_nac14h54XUDdH2M3xB-A',
#   'name': '데이터뽀개기 2018 등록 접수(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '10stUpn1ta3nzgHun0J_LwCOwPdah3gMqR9aifKvVXOA',
#   'name': '단톡방 정보',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Ieo1tfushcjU7Da3U2tlJ0h8yLpZ_rk5yY9KHKR3Ais',
#   'name': '애드파워 주소록-산책60대-2019년 1월',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1EJIu7BOb31CZdSEFKlOnv0d0I64-JAPIsqHGRzADzN0',
#   'name': '[타다] 드라이버 코호트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1kDHaZ4rr3tVsLXx0__WCFSAIv_-rcxsxdYe-05MCPz4',
#   'name': '싸이버스 - 일주일 스터디 전체 시간표',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '13MoUOhVtdNjWqrnqXa9gcBQ1i16vapfmCiEpnJorvWU',
#   'name': '스머프 2번째 모임',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '10tJAdzPy4E7nQHffFaAQAD_Uls6LIlYR51Khz600Yd0',
#   'name': '그냥 궁금해서 하는 설문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1DfOmLb-2UTfMTgZ4g3MIrKK57bvLquy-6zs75JfxNio',
#   'name': '[타임라인] Data Science is a Team Sports',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ZlIhIhFzKiuef5xCFqIMnIPLFyg70OEMrsMUlxGnsAg',
#   'name': '[일정]수학 애벌Lab(Math LarvaLab)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ZLVbKYpjV_8DwXs9VCkEtuU8_2TZwPrKtMqU4u3ptPk',
#   'name': '익명 연봉방의 결과 시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1WjPQYTocTzVZuW-6j9u4hea9KMQP8Cx8qjqaT7Q1m2E',
#   'name': '[모두연 플레이샵]내 인생의 도서 리스트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1W0t9cvzk55ZZDfFHjZNZmnIDFkpnP2F4ikgBftSELUU',
#   'name': 'vlookup',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1z3iHB0ZEBBUVyAPDQMksx-_f6Qhe7QjSBCgIgwa5RXk',
#   'name': '스타트업 사전 A to Z',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ONLmOWbhv3AwIGEMX07TdafK5rhEfHWjnEKLarb3NN4',
#   'name': 'BigQuery 특강 관련 설문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1q89X3Pcw6TK2GSqj0tYv64Bdspkvz9i0U3o2xCoM6TU',
#   'name': '글또 2기 피드백 및 조사(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1aprpUjKF75WmIzopH4WhzHahIeLpSE4BIjiIP9WL82A',
#   'name': 'results-20190519-212300',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1oQ1qlccZW4fRBHTVB8w3h_Jkg5I9ky9fJocLz_6EhYc',
#   'name': '동네 맛집',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1cTwfYLROLRmhLoGvDb9N4ouS3pzxCW5Sn9Y0uAUFvew',
#   'name': 'results-20190516-214554',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1-7uCGa1QpkerEuS7z4yWYuEX2PInYNMjq7g-hJdpAeQ',
#   'name': '영상편집비용 지불 내역',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1vamRRkbwXL1PurLbapyXX9CTLKPJZdDjZmVGoFAJtxY',
#   'name': '올인원 패키지 : 데이터 분석 실전(가제)_커리큘럼_변성윤님의 사본',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Sf2nfan43IEudUw4NZLMfi11680_hp5JcWS0F3DkBBY',
#   'name': '올인원 패키지 : 데이터 분석 실전(가제)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1XFvBoJdMfDEvotYogI0p8vFwz7efH9jlfc3INDvdgj8',
#   'name': '데이터 엔지니어링 Extension SCHOOL 팀프로젝트 관련 설문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1HsvbRmq1tRMBsnofdrn5jUSRd7LKw3_fD8WTIXpfD30',
#   'name': 'BboSubBi Study',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1wq66ElH8j_2lZHSICTd72hwG7mrH_pisMB4hQ3d4Xbk',
#   'name': 'Data Science_커넥트번역서포터즈',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1QhffZB84YU4IdJ9YgZKGc9OGgt-TKJ1B1L1-mBejkUM',
#   'name': '스머프(스타트업 머신러닝 플레이어) 모임 신청(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1--DriH7C8CN0QHKEsll_0u3SErxEkaynw7-lVmYsr2g',
#   'name': '딥놀주제모음',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ItfWx-di-L21zUIkR0sWwQCuhUrlLQVm2tyxY95K5U4',
#   'name': '스얼이 추천하는 스타트업 입문자가 팔로우하면 좋은 링크 모음집',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1p7UFb6TocxiJasa8Q7rCf2O21j0aXJKbBNNUk0FskqM',
#   'name': '[출석체크] 모객현황공유_파이썬을 활용한 시계열 분석 입문 1기 ',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1RG1dZfPEOQWnl8gmOrpeQHrENk5IZg9dgs668r9vefg',
#   'name': 'SCAI-NAVER Clova AI Workshop 참석자 명단',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1VarAov_k0iktuRlNUh_XgsmSN09O-h5Hy6jlG8Du7jA',
#   'name': '참석자 의견 조사 설문 (Responses)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1rQHH7mrWiqrMs18Rp6Sdc-AiT3xaHEyg8Dn8gthhoNM',
#   'name': '구글 클라우드 스터디잼 신청서(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1uWm5GzvKwc9STzxVhDHzxXDxgCsOgN0O8EVmyq6QalU',
#   'name': '머신러닝/딥러닝 스터디그룹 in Korea',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1XvLtXOLKKgbdllZtOFpLE0xS4iSQ2GxPdEmxzoM69-Q',
#   'name': '글또!!',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1jqJf9_UyoVPyNq0v305_9s90VbYuaNvR7FTJG_6kyXo',
#   'name': 'deepnol_개인정보',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1mYYegHLeYHAVPNQQdooQCY0Hvj2Ef8n2rgK-olxywhA',
#   'name': '2018 스밥 게스트 신청서(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1SFOtrxufl50uaAOW83CKW0BmDb2pOvXHbZ1EWhpKIf0',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1izRUldkJ4udJZWZCZMgcOcfORDL1jBI5Mf1kMy1W2nA',
#   'name': '글또 회고 모임 관련 설문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1IQg4swd9CMJdBUB3xqL0fD4kJ-IZtMoUSu42XaZ0eHk',
#   'name': 'DataBreak (전 캐글뽀개기) 운영진 모집 안내문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1iVu7SjmKHevMS7RHmBwARVx_eRAbUVF0LAWvcWc3DrM',
#   'name': '[GDG Campus Korea][2월 행사] 타임테이블 - 공개용',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Ccv-5PpW4zZgZSLSXdpPOYzEbNoffwmk0-FL3gWAmto',
#   'name': '00. 용어집',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1SxA716Icqnyn2k81p8B2y97axmEz5cgCcGLUdMgM3QM',
#   'name': '00. 사업소득 vs 기타소득',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1kuUBojnK-y-YxAiErRegYQBmOnt6RbMkTKXAp0ejWQc',
#   'name': '번역작업분담표',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1b5zl4t13pXO5wGHGoqYkV83uRy2ZpKCcwq1Yn43lSZ0',
#   'name': 'nlp_bootcamp_papers',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1btX-u6iDSdKZHAu20zLpuZFx_Affj2JcXldDVlbSKbw',
#   'name': '양식-제목없음(응답)의 사본',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1z3VU2JZIG-N2Bkr3VENvP9sGJGqJsfMyy6mjg8UmbdY',
#   'name': '뷰티음료에 대한 질문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1wlbqmT-_dxcUPSUJKxwJGXFlNvXaCKlaWHx1LW-b4FE',
#   'name': '1기 운영진',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1LidOMCtIa8EP5Sw4iC9ditmQIb1QT7DQEbnr9bWjfgE',
#   'name': '설문지-제목없음(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '197CdRMGDXWKh-9NEYyLOiK1lF-5ucUL4PYvsQdbbSfg',
#   'name': '맥주 설문조사3(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1UoNAGp--du_CAtKNqDnfdUa_kXnXbehCWiKBtgfSXDI',
#   'name': '맥주 설문조사2(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1LIJ_VAUoK29-VdyL1EZ9KeTrfN8xzQoiKEsS6izqkKY',
#   'name': '글또 2기 참여자 명단',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ShBgS-Z1RpD40lSIMs9x9Fbcy5-VtbZ-iV2whCDTS1I',
#   'name': '글또 2기 첫 모임 날짜 관련 설문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1lgRGPUsT_2Bbc69ppzKX5HCXlj7S5gS6fJGI6yt9fbc',
#   'name': 'Retrica KPIs 2016-2018',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '13etlIwpRPOL9aPzzHb_gUaQ2iu3rhrzQOndHZENFN2U',
#   'name': '데이터야놀자 x Little Big Data 발표자 정보',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1srLVm-KCM33O37ytIxLP1WdQGrct91hawxm19ePty6k',
#   'name': '이직을 위하여',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1X__jjbRLzG5taw_u9ss5nHrhGEBT8Mu_uO8Mmaxjrbg',
#   'name': '맥주 설문조사(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1QUFTvSgJQEFZZNWTPzo23xRs-FWlolJ-c5iGeI9-6ek',
#   'name': '뷰티음료 섭취 조사(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1KkEHg0FNX4eHBfEroYL-C6xS4mebX-83drxf2fiw3kI',
#   'name': 'DataBreak 2018 참가자 명단 및 자원봉사자 공지사항',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1gseVbJyrsgT2_4XUFGv2YEpgt2SPpEBtgYAbxnsWENo',
#   'name': '발표자',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1GVBjwnHPBDFro8ST8oEnbWbMTW0ZZfOTgrIyS9eEy7M',
#   'name': 'RTR Weekly Progress Status',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1XSbyjPibkJiQPpi29y9oLlMD9ihHvazb7L0uIS5wGA8',
#   'name': '"parkS" 스터디',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1mm9PTYYPBvEwT4YOv-zK9bUCs2nIcGCh_BwxN9m97Iw',
#   'name': '변수 정리',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '15OgrZKj6pD0jptFnkTIWioqC1_2_eoJidkysRXBlDyw',
#   'name': '워킹캐글 스터디 일정표',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1pvISUMxL6mrmMnlU01xPtRS2PCoXaywG10YSnp2drfE',
#   'name': '603. 6기 미션 도서 배정 내역',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1PTOdxgfUtlEpznHsI6fnEcGtVpDpmOLySedR3hZQBlc',
#   'name': 'Pycon 2018 젬 줍 배틀',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1BPWetSnhsshL00y6YO9oVQxYSlViKHAUSo5Top14HhE',
#   'name': '마공수첩 계산기',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '117pDcqigxY9OEJcZeqD_N3xMg1cNAxArqklE6w-E_oM',
#   'name': '하이퍼커넥트 대회',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Oenddr8vMfBosCC8PEzFVGd3jHGoJ3LEncY9ZeTDV7A',
#   'name': '00. 사업소득 vs 기타소득',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1azsh0jYfwzFl7jPZLlvuUgUixwqJlI-38BKl0YjMlk4',
#   'name': '이직을 위하여(샘플)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '15BNk-7cuEi5DJZPTlL-K8nGVDOMiKTSgMt1jrf2-hHo',
#   'name': 'DEES_1기_2학기_Daily Report',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ZvHSWYY1u-3M7sOdyz6TcMyWSA6URUoSVieDpSgXiTw',
#   'name': '데이터 엔지니어링 Extension SCHOOL 1기 2학기 관리(클매용)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1FgQomj2jM44kwQPHEd5-QNqB3lNM5dloPx1Gctv2BB8',
#   'name': 'Java 웹 프로그래밍 마스터 2기 커리큘럼_외부 공유용',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '11tf2o9BZGZS6yI7Zq1tr9mCh52cmD7uiMRyxC7cralc',
#   'name': '데이터그램 시즌3 - 커리큘럼.xlsx',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1pR1bVSs_tLG6TppqCTaIFYxyeIcbCMCg2JGXHEaq4zo',
#   'name': '6/5-실습',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1_FrGa3sKp3GotDD6VxY-83pyeSH9XZZiryo2JHB_eiE',
#   'name': '데엔스 개인별 목표 중간체크',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1_aebhQ7b8gfvgy07mKSFc6X_8kywt_1ko3Vlpfh73CM',
#   'name': '집중도 체크 예시',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1LNyCqIcFn2_KsLG8mIpbES-4nhjGq-rzYf1ISupCXoA',
#   'name': '인하대 특강 피드백(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '11QaXMgEHQ8i-KqP3DISvzbKfkxS-qEKlanCDTjVcxq0',
#   'name': '인하대 데이터 특강 참여 신청서(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1zK1l8uwruOAgJTFE9YbmCb2jYgYvAKFGNlEYr0_9lNw',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1AsRMi7UmrvvWJimRX13qXPy5P_WYV3nLzM9sF1d2lA0',
#   'name': 'nsml_어텐션뽕',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ls4WmCyFyti3f_o5aFeFvKH-OBakCJjnregaBN61-k8',
#   'name': 'LBD #1 연사&패널',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '137tHYtK3r-vGWuSWFdpGm7Bmj7x5fu6Cu0y_uhN91_Y',
#   'name': '602. 6기 미션/보상 상태 확인 시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1wVt4kfkKf56wwyg98_v25-Omefh-SNTpn4EUOXTqZuw',
#   'name': '샘플 데이터',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1cuTgXvEGqdnEPJ04wi0l8iomgSx0vlM7tsFWcIOIMcE',
#   'name': 'with GCP 2017 참가 신청자 입금 현황',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1AFen9Xo0cgq7AaqupJU_7t10x9fu32x6Bzwb58HfuGc',
#   'name': 'with GCP 2017 자원봉사자 신청서 (Responses)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1OAIHrZiIHhMmeO6ygLL1XYdBSS-j_zWhwJh4DklqkHQ',
#   'name': '코드스쿼드-사무실-위시리스트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1RvH1GV5DPvAvJHHlmBH4Sf760i6tHSWUQXIIdBuwQzk',
#   'name': '스타트업 인턴 매칭 프로그램 참가 기업 List (홈페이지 링크용)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1xol9Mp7L2KTvrByjCJnSAacJASOSvGIylC4Aouq0DiE',
#   'name': '[김성동 강사님] 모객현황 공유_PyTorch로 시작하는 딥러닝 입문_3기',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1-kI9rxg8v569pY4-OBWAmavSAFqSF6l5ORCuA_j_SuM',
#   'name': '2기 진행 현황 (17.01 ~)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1wYNJrhG5rA8E06VUi6x_fAroBXW6eTtOBzapa-RYrM0',
#   'name': '스밥 게스트/호스트 리스트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1dp9wqxlWSbiEdgr0UYaZgnqYUBhS8GSaY_O4RzHcquQ',
#   'name': 'PyTorch로 시작하는 딥러닝 입문 CAMP 중간 설문(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1kR8cGKXDvYGBVVQSuieFhJnYkTCj8EHoYMBWdtr5aW0',
#   'name': 'recolabs part2 스터디 정보',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1_nVAA0LGNiZtOsyyc1vtDRj9-WJheUKVktQsPwI9ytI',
#   'name': '2018 스밥 3기 운영진 연락처',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1k7jYPcpG4My-6KXln5ZnD29m1YrTWfyEjz682tjd5TE',
#   'name': '전국생활코딩 질문&답변',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1oKrKTh_HIAOy7Bz-O5wENRBehVnzW6VTlXRSwDA2jr4',
#   'name': 'with GCP 2017 참가자 명단',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1WSQ-09VCpOxm13RsIi18M2V_EDVSEnhhInexp5OkMno',
#   'name': '함수산책(Part5) 스터디 일정표',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1jzjXM37mWFQCj02nTnF1erOK5DtZRRzjyQcukzvan7g',
#   'name': 'withGCP 2017 총 지출 내역 정리',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Q4gkQZ0D-6G7gwJA5HmfQDOohcFVm3Wetb3meCnbESI',
#   'name': 'with GCP 2017 준비 현황',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1lO8Cp4RWT4c9jZVWS2j1QItyX7rR2oNZf1EBE3aZDlg',
#   'name': 'with GCP 2017 예산',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Tp08LfPMEF66c3unFM2EcSqawKaj9s0KTCk2qDtoTAo',
#   'name': 'with GCP 2017 시간표',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1W8H9WQcN8BoZ_IDyizL9n8eIMU-QfZX__8fLCTgSM6A',
#   'name': '소원수리 취합',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1NreDr2Ot0JmAbV7gcVuSszLALc7JB4yfXIVUQlBRtjk',
#   'name': 'with GCP 2017(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '184ioXPVCJehtJHtNN_noRkRMWnMXBoiKr6-u7RcRqvY',
#   'name': '물품 거래처 정보',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1OaF1CWEDYj0-EimneIZp69GUmxYwOr8NMl9-a8Cmd6o',
#   'name': '컨텐츠 세대차이 연표',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Ajl5Su4eGT89fx03KkfAK-fh4-is9-gYF_tnPcZISzQ',
#   'name': 'with GCP 2017 발표 지원서(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1RMYHxtTXSOqxMT9COC1yQaSV6GLMMDCTbbs7BoLLHx4',
#   'name': '11/16 스밥 농식품·관광 분야 스타트업 모임 (응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1XI4k4isqYOqU4EMWtHSSfIjosX2QbeOgHyIX8kBSxKI',
#   'name': '작업하기 좋은, 스터디하기 좋은 카페',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1P8e8WsB1DOJ58dPtsU45Qqw_GiivbIVGuuypVMD1jCs',
#   'name': '싸이랭-커리큘럼',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1AIioEWydS5c_QR5p2CPvAY3-zq96GWwhDUXTbMrNPLk',
#   'name': '데이터 사이언스 스쿨 2기 스몰 프로젝트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1N7b02635APf4ILacrnp4-uK4Ij0KX73ZpIaZk76iey4',
#   'name': '책 읽는 프로그래머 리뷰 1차_(OB회원)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1uAIQRxn-nBCwZ1_o7hFRfDIwadn6jd7CPtSoFdoCS3I',
#   'name': 'DATA_JOURNALISM_KR_LIST',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '13Z4aKlOlLvYYipa73db-7Odf5JMGdm3k75s-0wXomEc',
#   'name': '공공데이터포털 모음 (2017-06-25)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1LPzjvYeTB1FuHMFPRnCt1App00jspnt3Za-WXw0nntI',
#   'name': '스케쥴/후기 포스팅 관리 ',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '19MO5eePLNSrlGZU_BAOCOrxr18Hjcr09ANJGhsXeNwc',
#   'name': '채용 상담 신청양식',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1RNtXB-kNblnfHyJNcMNtDx_2djnrmJAXfP38umkvo5g',
#   'name': '그로스해킹네트워크',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1K0tSZPwpg2oRnsA3DE9le-fxOnHILbYF2ZWUb1lrDMw',
#   'name': '2017_03_블루_iOS_&_FE',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1_IAooXcLH7Zva4W9tNEHrxE24GulBa5LfdB7kr5--SA',
#   'name': '베타 리딩 결과',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '12BUWZbhaetmeU7llxkdf7H25Z0Zcu1Au9XByXXNSISY',
#   'name': '데이터 사이언스 SCHOOL 1기 개별 프로젝트 관리',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1sMMSXSlbEA56hlVulCymQHrYdxh_Bjb0KctZk7ESmOc',
#   'name': '스쿨 HIRING DAY_161222',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1D9G7L6IvVezJ-X3fgWnw3AsCrU_-iiIgUNwoFg6pkRs',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1-EMY61d1YWs-8MsxWGGTGk5iavvOYmTPkXWghpYFwWg',
#   'name': '챌린지리그_Table및변수정의서',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1yf6TxbxmnrmO8edFhqEY9QqaFbbE975VSgiqDKD2VRU',
#   'name': '판교 출퇴근하기 좋은 중형 이하 아파트 총정리!',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1KNxLxUxdANC5p1o5FQOYbrpT0L5u3FfJQWs4kBW7QD0',
#   'name': 'BOAZ - 서울시 빅캠퍼스 명단',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1cq693svDWZUbnI-YN-F2uTW0G1QczB8O1EJeP2wKirE',
#   'name': 'Table 및 변수 정의',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ZtnLXylwHNBp1pNF_1T88RQWWwlHhrFOzy9WNcA1wvY',
#   'name': '데이터 사이언스 SCHOOL 2기_Daily Scrum',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1dRqhIAMbCUKFWWKg7RF58RnvdFJICh6h90DhxlwspDE',
#   'name': 'cohort.csv',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1cnRSa6raOl4LClhEfq7R2ydJiso8EZvU3nmbSe94m9I',
#   'name': '신용 관리와 소비생활(조향숙)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '180Rsf1kYObubvDX2ZJYo1dhyv2kjxliJmsU2R5_WMpc',
#   'name': '인간의 성장과 발달(이완정)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '11NDRAtZLuVQGq5sghAU6cpTwTpApsTCv9AuRkWPyN_w',
#   'name': '맥주 설문조사4(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Ly042rK7d0OC90Bypd_xKH9gXUkSMS1fnjU4FqhT__Q',
#   'name': 'ㅁㅈㄱ',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1K3SX7gZGcTLSXsgDOTTeMEAiE5OkHaANCBXWGuDK9-c',
#   'name': '[스위처]1차배송명단',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1tpyp2BiT4xHhowZep7sbhOcn3LcMH_uNo9qSB7tRBLs',
#   'name': '취업을 위한 글쓰기(김명임)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1mUWn_zNawdx8it0Fj5RJKyMcGKvTUIpIaBbS6-afkEo',
#   'name': '결혼과 부모역할(최난경)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1Cqam6465VKRUbxApgu7eaT0qy1OeZWfUoW_EHBntrzw',
#   'name': '신용관리와 소비생활(조향숙)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1unbRoitBp4_raYTwdQWHuOe7toS13ZXUIdW7Yu3kSgE',
#   'name': '경제학의 이해 (이명운)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '17kL4uw8g0lRxb7xUdygXIZ-XGHvH8aSOSCOWZHrmqe4',
#   'name': '초특급프랑스어(최인경)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1ep7sfWWIXlWF-PEm6wULgJYSL6pGUhoSmYc5c9BPQTk',
#   'name': '인간의 성장과 발달(강완숙)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1eGsEGJnb3SS-I_q0muNf_87WiACrp66xcKd7lf5XY10',
#   'name': '그래두의 비밀',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1dQDGzBTm4OXyg_PEpwpFf0WAWYy_w9dSxrLP8Mg3NuE',
#   'name': '14회 애드캠프 연명부',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1-vwiH7V5PUcjH3qaqbU-K0-JB_F182weGr4eOeO0dJc',
#   'name': '제목 없는 스프레드시트',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '1_CzigUz54iikeM4bDKWc38Y_APbCvcf-XRA3GjO9V40',
#   'name': '주요 프레지 모음',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'},
#  {'kind': 'drive#file',
#   'id': '19SQFV2qxCmELSrslMBkbucpqqGTcAkaXAzoPZZRFDZs',
#   'name': '양식-제목없음(응답)',
#   'mimeType': 'application/vnd.google-apps.spreadsheet'}]
